# %% [markdown]
# # Introduction
#
# EDA and visualization of IMDb Movie Dataset
#
# This data set contains information about 10,000 movies collected from The Movie Dataset (TMDb), including user ratings and revenue.
#
# The last two columns (*.adj) show the budget and revenue adjusted for inflation over time

# %%
# Import all the libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns       
import numpy as np
from matplotlib import cm
# %matplotlib inline 
# inline the matplot to show plot in the cell

# %%
df = pd.read_csv('tmdb-movies.csv')

# peak of the first 5 rows of the data
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
# drop some unuseful columns to this project, inplace = True to renew df

df.drop(['id','imdb_id', 'homepage','overview'],axis=1,inplace=True)  
df.drop_duplicates(inplace=True)
df.head()
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# ...

# %% [markdown]
# # Data Wrangling

# %%
# check the dimension(raw, column) of the df

df.shape
# Out:
# (10866, 17)

# %%
# check the datatypes 
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
# check the unique value in each columns to find any duplicate data
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
# summary of the whole dataset
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
# check how many null values in each column

df.isnull().sum().sort_values(ascending = False) # sort pandas.core.series.Series in descending order

# seems to have some missing/null values in tagline, keywords... luckily those are string data
# Out:
# tagline                 2824
# keywords                1493
# production_companies    1030
# cast                      76
# director                  44
# genres                    23
# popularity                 0
# vote_count                 0
# budget_adj                 0
# release_year               0
# vote_average               0
# runtime                    0
# release_date               0
# budget                     0
# original_title             0
# revenue                    0
# revenue_adj                0
# dtype: int64

# %%
type(df.isnull().sum())
# Out:
# pandas.core.series.Series

# %%
df.drop_duplicates(inplace=True)

# %%
# check the distribution of each variables
df.hist(figsize=(15,15));

# %%
# seems like budget and revenue are heavily skewed, lets have a closer look

fig,a = plt.subplots(2, 2, figsize = (15,10))


a[0,0].set_xlabel('budget', fontsize = 10)
a[0,0].set_ylabel('count', fontsize = 10)
a[0,0].hist(df['budget'], bins = 100, edgecolor = 'white')

a[0,1].set_xlabel('budget', fontsize = 10)
a[0,1].set_ylabel('sqrt(count)', fontsize = 10)
a[0,1].hist(np.sqrt(df['budget']), bins = 100, edgecolor = 'white')

sns.boxplot(x = df['budget'], data = df['budget'], ax = a[1,0])
a[1,0].set_xlabel('budget', fontsize = 10)

a[1,1] = sns.boxplot(x = np.sqrt(df['budget']), data = np.sqrt(df['budget']))


# applying square root transformation still result in heavily skewness

# %%
df["log_budget"] = np.log(df['budget'].add(0.1)) # add 0.1 since there are bedget = 0

fig,a = plt.subplots(1, 2, figsize = (15,15))
sns.histplot(df.log_budget, ax = a[0])
sns.boxplot(data = df.log_budget, ax = a[1])

# although not a bell shape, log transformation of budget gives better boxplot with no outlier
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Exploration

# %%
# plot a scatterplot of budget and popularity to get a sense whether they are assocition

fig, ax = plt.subplot()
ax.set_xlable('budget')
ax.set_ylable('popularity')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/simon/data_analysis/movie/movie.ipynb Cell 18' in <module>
#       <a href='vscode-notebook-cell:/home/simon/data_analysis/movie/movie.ipynb#ch0000018?line=0'>1</a> # plot a scatterplot of budget and popularity to get a sense whether they are assocition
# ----> <a href='vscode-notebook-cell:/home/simon/data_analysis/movie/movie.ipynb#ch0000018?line=2'>3</a> fig, ax = plt.subplot()
#       <a href='vscode-notebook-cell:/home/simon/data_analysis/movie/movie.ipynb#ch0000018?line=3'>4</a> ax.set_xlable('budget')
#       <a href='vscode-notebook-cell:/home/simon/data_analysis/movie/movie.ipynb#ch0000018?line=4'>5</a> ax.set_ylable('popularity')
#
# TypeError: cannot unpack non-iterable AxesSubplot object
